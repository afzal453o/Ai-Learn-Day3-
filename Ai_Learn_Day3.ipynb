# %% [markdown]
# <a href="https://colab.research.google.com/github/afzal453o/Ai-Learn-Day3-/blob/main/Ai_Learn_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STEP-BY-STEP FIX FOR COLAB

# %%
# %%writefile helper_functions.py
def print_llm_response(prompt):
    print(f"LLM response:\n{prompt}")

def get_llm_response(prompt):
    return f"LLM response:\n{prompt}"
# Out:
# Overwriting helper_functions.py

# %%
from helper_functions import print_llm_response, get_llm_response

# %%
name = "Fatin"
prompt = f"""
Write a four line birthday poem for my friend {name}.
The poem should be inspired by the first letter of my friend's name.
"""
print_llm_response(prompt)
# Out:
# LLM response:
#
# Write a four line birthday poem for my friend Fatin.
# The poem should be inspired by the first letter of my friend's name.

# %% [markdown]
# Creating a list

# %%
friends_list = ["Tommy", "Isabel", "Daniel"]
print(friends_list)
# Out:
# ['Tommy', 'Isabel', 'Daniel']

# %%
len(friends_list)
# Out:
# 3

# %%
prompt = f"""
Write a set of four line birthday poems for my friends {friends_list}.
The poems should be insipred by the first letter of each friend's name.
"""
print(prompt)
# Out:
# Write a set of four line birthday poems for my friends ['Tommy', 'Isabel', 'Daniel'].
# The poems should be insipred by the first letter of each friend's name.

# %% [markdown]
# Adding another element  and remove to the list

# %%
# add single element to list
friends_list.append("Alex")
print(friends_list)
# Out:
# ['Tommy', 'Isabel', 'Daniel', 'Otto', 'Otto', 'Alex']

# %%
#using remove
friends_list.remove("Tommy")
print(friends_list)
# Out:
# ['Isabel', 'Daniel', 'Otto', 'Otto', 'Alex']

# %%
list_of_tasks = [
    12,15,30,10,40
]

task = list_of_tasks[0]
print_llm_response(task)
# Out:
# LLM response:
# 12

# %% [markdown]
# Extra practice

# %%
# Create a list with the titles
# of five of your favorite movies

### WRITE CODE HERE ###
movie_list = ["Titanic", "Inception", "Interstellar", "Avatar", "The Dark Knight"]
### --------------- ###

# %%
# Fix the bug in the following code

prime_numbers = [2, 3, 5, 7, 11]

### FIX THIS CODE ###
print(prime_numbers[3]) #access and print() the fourth element
### --------------- ###
# Out:
# 7

# %%
# Add one name to friends_list using append

friends_list = ["Tommy", "Isabel", "Daniel", "Otto"]

### WRITE CODE HERE ###

### --------------- ###
friends_list.append("Alex")

print(friends_list)
# Out:
# ['Tommy', 'Isabel', 'Daniel', 'Otto', 'Alex']

# %%
# In the following code, remove the country
# that is not in South America

countries_in_south_america = ["Colombia", "Peru",
                              "Brasil", "Japan",
                              "Argentina"]
countries_in_south_america.remove("Peru")

### WRITE CODE HERE ###

### --------------- ###

print(countries_in_south_america)
# Out:
# ['Colombia', 'Brasil', 'Japan', 'Argentina']
